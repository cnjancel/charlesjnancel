# %% [markdown]
# # STAT 207 Lab Assignment 6 - Individual Part - [23 total points]
#
# This individual assignment will contain two case studies.
#
# * <u>Case Study 1</u>: Predicting Coffee Flavor *for New Coffee Brands*
# * <u>Case Study 2</u>: Modeling Breast Tumor Radius Means
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:163pt;">
#     <tbody>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:87pt;">Problem</td>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:76pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">6</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">7.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">8.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">9.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">9.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">9.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">9.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">9.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">10.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">10.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# # <u>Case Study 1</u>: Predicting Coffee Flavor *for New Coffee Brands*
#
#
#
# ### Coffee Dataset Information
#
# In this individual assignment we will return to the `coffee.csv` dataset. Information about the variables in this dataset can be found here: https://corgis-edu.github.io/corgis/csv/coffee/
#
#
# ### Research Goals
#
# In this individual assignment we would ideally like to pursue multiple research goals.
#
# #### Main Research Goal
#
# Our main research goal will be to create a predictive model that effectively predicts the `Flavor` of *new coffee brands*.
#
#
# #### Secondary Research Goals
#
# Ideally, the predictive model that we select will also be able to accurately reflect the relationship between the explanatory variables and the response variable `Flavor`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette("rocket")

# %% [markdown]
# ## 1. Coffee Dataset
#
# ### 1.1. Reading the csv
#
# 1. Read the `coffee.csv` into a dataframe. The strings that are used to represent missing values in this csv file are represented with 'nan'. Luckily, 'nan' is one of the string values that the **pd.read_csv()** function is automatically programmed to detect as a missing value and thus convert into a NaN type object.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
coffee = pd.read_csv("coffee.csv")
coffee.shape[0]
# Out:
# 989

# %%
coffee.head(5)
# Out:
#   Location_Country                Location_Region  Location_Altitude_Min  \
# 0    United States                           kona                      0
# 1           Brazil  sul de minas - carmo de minas                     12
# 2           Brazil  sul de minas - carmo de minas                     12
# 3         Ethiopia                         sidamo                      0
# 4         Ethiopia                         sidamo                      0
#
#    Location_Altitude_Max  Location_Altitude_Average  Year  \
# 0                      0                          0  2010
# 1                     12                         12  2010
# 2                     12                         12  2010
# 3                      0                          0  2010
# 4                      0                          0  2010
#
#                          Data_Owner Data_Type_Species Data_Type_Variety  \
# 0  kona pacific farmers cooperative           Arabica               NaN
# ...

# %% [markdown]
# ### 1.2. Dropping NaN Values
#
# We only intend to use the `Flavor`, `Aroma`, `Aftertaste`, `Color`, and `Species` variables in this dataframe.
#
# 1. Create a dataframe with just these variables.
# 2. Then drop all rows from this dataframe that have a NaN value.
# 3. How many rows did you drop?

# %%
FAACS = coffee[["Data_Scores_Flavor", "Data_Color", "Data_Type_Species", "Data_Scores_Aftertaste", "Data_Scores_Aroma"]]

# %%
FAACS = FAACS.dropna()

# %%
FAACS.shape
# Out:
# (942, 5)

# %%
coffee.shape[0]-FAACS.shape[0]
# Out:
# 47

# %% [markdown]
# ### 1.3. Dropping a Large Outlier
#
# This dataset has a prominent outlier with an `Aroma` rating that is equal to 0. Drop this observation from the dataset.

# %%
FAACS_cleaned = FAACS[FAACS["Data_Scores_Aroma"] != 0]
FAACS_cleaned
# Out:
#      Data_Scores_Flavor    Data_Color Data_Type_Species  \
# 0                  8.42       Unknown           Arabica
# 1                  7.92       Unknown           Arabica
# 2                  7.92       Unknown           Arabica
# 3                  8.00       Unknown           Arabica
# 4                  7.83       Unknown           Arabica
# ..                  ...           ...               ...
# 983                7.00         Green           Arabica
# 984                7.67         Green           Arabica
# 986                7.75       Unknown           Robusta
# 987                7.75  Bluish-Green           Robusta
# 988                7.42    Blue-Green           Arabica
#
#      Data_Scores_Aftertaste  Data_Scores_Aroma
# 0                      8.08               8.25
# 1                      7.92               8.17
# 2                      8.00               8.42
# 3                      7.83               7.67
# 4                      7.58               7.58
# ...

# %% [markdown]
# ## 2. Training and Test Datasets
#
# We intend to build linear regression models that will predict the `Flavor` of *new coffee brands* using some of the following explanatory variables.
#
# * `Aroma`
# * `Aftertaste`
# * `Color`
# * `Species`
#
#
# Using some combination of these explanatory variables, we'd like to build and select a linear regression model which we can infer might perform well when it comes to predicting the `Flavor` of *new coffee brands*. Thus, let's create a training and a test dataset from our cleaned dataframe from 1.3.
#
# Use a random state of `437` to do this. Your training dataset should be 80% of observations from your cleaned dataframe.

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(FAACS_cleaned, test_size=0.2, random_state=437)
df_test.shape[0]/FAACS_cleaned.shape[0]
# Out:
# 0.20085015940488843

# %% [markdown]
# ## 3. Full Model
#
# ### 3.1. Fitting the Full Model
#
# Next, fit the "full" linear regression model that predicts `Flavor` with
#
# * `Aroma`
# * `Aftertaste`
# * `Color`
# * `Species`.
#
# Display the summary output table for this model.

# %%
import statsmodels.formula.api as smf
fm = smf.ols(formula = "Data_Scores_Flavor~Data_Scores_Aroma+Data_Scores_Aftertaste+Data_Color+Data_Type_Species", data=df_train).fit()
fm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Data_Scores_Flavor   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     452.7
# Date:                Tue, 03 Oct 2023   Prob (F-statistic):          1.39e-244
# Time:                        23:53:44   Log-Likelihood:                 308.52
# No. Observations:                 752   AIC:                            -603.0
# Df Residuals:                     745   BIC:                            -570.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 3.2. Linear Regression Equation
#
# Write out the linear regression equation for this model. Make sure to use appropriate notation.

# %% [markdown]
# $\text{Flavor} = 0.2847 -0.0379*\text{Blueish Green} +0.0064*\text{Green} + .0017*\text{Unknown} -.0403* \text{Robusta} +.2730* \text{Aroma} +.6988*\text{Aftertaste}$

# %% [markdown]
# ### 3.3. Test Dataset Fit
#
# Calculate the test R^2 of this full model.

# %%
from sklearn.metrics import r2_score
y_test = df_test["Data_Scores_Flavor"]
y_pred_test = fm.predict(df_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.8042929986484548

# %% [markdown]
# ## 4. Model with Interaction Terms
#
# Next, let's consider incorporating interaction terms into this full model.
#
# ### 4.1. Finding Interactions between Categorical and Numerical Explanatory Variable Pairs
#
# 1. For every `categorical explanatory variable` and `numerical explanatory variable` pair in the <u>training dataset</u>, evaluate if there is an interaction between these two terms in how they impact the predicted `Flavor` response variable.
# 2. Which one of these `categorical explanatory variable` and `numerical explanatory variable` pairs has the *weakest* interaction?
#
# Hint: You should create 4 plots to help you answer this question.

# %% [markdown]
# From the plots, we can observe:
#
# * The lines in each plot represent different levels of the categorical variables.
# * Non-parallel lines suggest an interaction between the categorical and numerical variable.
#
# Based on the plots:
#
# * The interaction between Data_Type_Species and Data_Scores_Aftertaste appears to be the least pronounced, suggesting it might be the weakest interaction.

# %%
categorical_vars = FAACS_cleaned.select_dtypes(include=['object']).columns.tolist()
numerical_vars = FAACS_cleaned.select_dtypes(exclude=['object']).columns.tolist()

categorical_vars, numerical_vars
# Out:
# (['Data_Color', 'Data_Type_Species'],
#  ['Data_Scores_Flavor', 'Data_Scores_Aftertaste', 'Data_Scores_Aroma'])

# %%
sns.lmplot(x = "Data_Scores_Aroma", y = "Data_Scores_Flavor", hue = "Data_Color", ci = False, data=df_train)
plt.show()

# %%
sns.lmplot(x = "Data_Scores_Aroma", y = "Data_Scores_Flavor", hue = "Data_Type_Species", ci = False, data=df_train)
plt.show()

# %%
sns.lmplot(x = "Data_Scores_Aftertaste", y = "Data_Scores_Flavor", hue = "Data_Type_Species", ci = False, data=df_train)
plt.show()

# %%
sns.lmplot(x = "Data_Scores_Aftertaste", y = "Data_Scores_Flavor", hue = "Data_Color", ci = False, data=df_train)
plt.show()

# %% [markdown]
# ### 4.2. Incorporating Interaction Terms
#
# Select the top three `categorical explanatory variable` and `numerical explanatory variable` pairs that you identified in 4.1 that display the *strongest* interaction between how they impact the `Flavor` response variable. Then incorporate the interaction terms that model this interaction effect of your three chosen `categorical explanatory variable` and `numerical explanatory variable` pairs into the full model.
#
# Fit this new model with the **training dataset** again and display the summary output table.

# %%
IntTerms_form = "Data_Scores_Flavor~Data_Scores_Aroma+Data_Type_Species+Data_Color+"
IntTerms_form += "+Data_Scores_Aftertaste*Data_Color"
IntTerms_form += "+Data_Scores_Aftertaste*Data_Type_Species" 
IntTerms_form += "+Data_Scores_Aroma*Data_Type_Species"

# %%
IntTerms_fm = smf.ols(formula= IntTerms_form, data = df_train).fit()
IntTerms_fm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Data_Scores_Flavor   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     250.0
# Date:                Tue, 03 Oct 2023   Prob (F-statistic):          1.40e-240
# Time:                        23:53:45   Log-Likelihood:                 314.18
# No. Observations:                 752   AIC:                            -604.4
# Df Residuals:                     740   BIC:                            -548.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 4.3. Linear Regression Equation
#
# Write out the linear regression equation for this model. Make sure to use appropriate notation.

# %% [markdown]
# $ \text{Flavor} = 1.3679 + 1.4570 \times \text{Species}_{[T.Robusta]} - 0.3223 \times \text{Color}_{[T.Bluish-Green]} - 1.1256 \times \text{Color}_{[T.Green]} - 1.6248 \times \text{Color}_{[T.Unknown]} + 0.2791 \times \text{Aroma} - 0.3029 \times \text{Aroma:Species}_{[T.Robusta]} + 0.5476 \times \text{Aftertaste} + 0.0386 \times \text{Aftertaste:Color}_{[T.Bluish-Green]} + 0.1516 \times \text{Aftertaste:Color}_{[T.Green]} + 0.2177 \times \text{Aftertaste:Color}_{[T.Unknown]} + 0.1111 \times \text{Aftertaste:Species}_{[T.Robusta]} + \epsilon $

# %% [markdown]
# ### 4.4. Test Dataset Fit
#
# Calculate the test R^2 of this full model.

# %%
y_pred_test = IntTerms_fm.predict(df_test)
r2_score(y_test, y_pred_test)
# Out:
# 0.8033620739423805

# %% [markdown]
# ## 5. Model Evaluation
#
# ### 5.1. Primary Research Goal
#
# Does the full model or the interaction model better help us meet our primary research goal? Explain.

# %% [markdown]
# For the main research goal of prediction, the interaction model is slightly preferred based on the given metrics, but the difference is small. Further evaluation on new data might be beneficial.

# %% [markdown]
# ### 5.2. Seconary Research Goal
#
# Does the full model or the interaction term model more accurately reflect the relationship that exists between the explanatory variables and the `Flavor` response variable in the training datset? Explain.

# %% [markdown]
#    For the secondary research goals of understanding relationships, the interaction model provides a more detailed and nuanced representation and is thus preferred.

# %% [markdown]
# # <u>Case Study 2</u>: Modeling Breast Tumor Radius Mean
#
#
# ### Wisconsin Breast Cancer Dataset
# In our second case study, we will examine a dataset comprised of information about 569 breast tumors (malignant 'M' and benign 'B').The column features in this dataset are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image.
#
#
# ### Research Goal
#
# We intend to build linear regression models that will accurately model the relationship between the `radius_mean` of breast tumor image data the following explanatory variables in **the full dataset**.
#
# * `texture_mean`
# * `perimeter_mean`
# * `area_mean`
# * `diagnosis`

# %% [markdown]
# ## 6. Breast Tumor Dataset
#
# 1. Read the `wdbc.csv` into a dataframe. There are no implicit or explicit missing values in this dataset.
# 2. Show the first 5 rows.
# 3. Show how many rows this dataframe has.

# %%
wdbc = pd.read_csv('wdbc.csv')
wdbc.shape[0]
# Out:
# 569

# %%
wdbc.head(5)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0

# %% [markdown]
# ## 7. Preliminary Analysis
#
# ### 7.1. Numerical Variable Relationships
#
# 1. For each pair of numerical variables [`radius_mean`,`texture_mean`, `perimeter_mean`, `area_mean`], plot a scatterplot.
# 2. Which numerical explanatory variable displays the strongest *linear* relationship with the `radius_mean` response variable?

# %%
numerical_vars = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']

sns.pairplot(wdbc[numerical_vars])
plt.show()

# %% [markdown]
# ### 7.2. Diagnosis Association with Radius Mean
#
# Is there an association between the tumor `diagnosis` (malignant or benign) and the `radius_mean` variable in this dataset?

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=wdbc['diagnosis'], y=wdbc['radius_mean'])
plt.xlabel('Diagnosis (0: Benign, 1: Malignant)')
plt.ylabel('Radius Mean')
plt.title('Association between Tumor Diagnosis and Radius Mean')
plt.show()

# %% [markdown]
# Yes, there is a strong association between the tumor `diagnosis` (malignant or benign) and the `radius_mean` variable in this dataset. Malignant tumors generally have a larger `radius_mean` compared to benign tumors.

# %% [markdown]
# ## 8. Full Model
#
# ### 8.1. Fitting the Full Model
#
# Next, fit the full model that predicts `radius_mean` with
#
# * `texture_mean`
# * `perimeter_mean`
# * `area_mean`
# * `diagnosis`
#
# Show the summary output table for this model.

# %%
full = smf.ols(formula = "radius_mean~texture_mean+perimeter_mean+area_mean+diagnosis", data=wdbc).fit()
full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            radius_mean   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 3.707e+04
# Date:                Tue, 03 Oct 2023   Prob (F-statistic):               0.00
# Time:                        23:53:46   Log-Likelihood:                 62.640
# No. Observations:                 569   AIC:                            -115.3
# Df Residuals:                     564   BIC:                            -93.56
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 8.2. Linearity Assumption
#
# 1. Does this full model meet the linearity assumption?
# 2. Is a linear regression model a suitable type of model to reflect the relationship between the response variable `radius_mean` and the explanatory variables `texture_mean`, `perimeter_mean`, `area_mean`, `diagnosis` in this dataset? Explain.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

sns.scatterplot(x=wdbc['texture_mean'], y=wdbc['radius_mean'], ax=axes[0, 0])
axes[0, 0].set_title('Scatter Plot for texture_mean vs radius_mean')

sns.scatterplot(x=wdbc['perimeter_mean'], y=wdbc['radius_mean'], ax=axes[0, 1])
axes[0, 1].set_title('Scatter Plot for perimeter_mean vs radius_mean')

sns.scatterplot(x=wdbc['area_mean'], y=wdbc['radius_mean'], ax=axes[1, 0])
axes[1, 0].set_title('Scatter Plot for area_mean vs radius_mean')

sns.scatterplot(x=wdbc['diagnosis'], y=wdbc['radius_mean'], ax=axes[1, 1])
axes[1, 1].set_title('Scatter Plot for diagnosis vs radius_mean')

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the scatter plots, `perimeter_mean` and `area_mean` exhibit strong linear relationships with `radius_mean`. While `texture_mean` has a weaker linear relationship, `diagnosis` clearly differentiates between the `radius_mean` of benign and malignant tumors. A linear regression model can capture these relationships, but due to potential non-linearities (e.g., in `texture_mean`), other models might offer better fits.

# %% [markdown]
# ## 9. Transformed Model
#
# ### 9.1. Square Root Area Mean
#
# Next, create a new variable in your dataset that is the **square root** of the `area_mean` variable.
#
# *Hint*: np.sqrt()

# %%
import numpy as np

wdbc['sqrt_area_mean'] = np.sqrt(wdbc['area_mean'])
wdbc[['area_mean', 'sqrt_area_mean']].head(5)
# Out:
#    area_mean  sqrt_area_mean
# 0     1001.0       31.638584
# 1     1326.0       36.414283
# 2     1203.0       34.684290
# 3      386.1       19.649427
# 4     1297.0       36.013886

# %% [markdown]
# ### 9.2. New Preliminary Analysis
#
# Now, for each pair of numerical variables in the list [`radius_mean`,`texture_mean`, `perimeter_mean`, **`sqrt(area_mean)`**], plot a scatterplot.

# %%
sns.pairplot(wdbc[["radius_mean", "texture_mean", "perimeter_mean", "sqrt_area_mean"]])
plt.show()

# %% [markdown]
# ### 9.3. Transformed Model
#
# Next, fit a new model that predicts `radius_mean` with
#
# * `texture_mean`
# * `perimeter_mean`
# * **`sqrt(area_mean)`**
# * `diagnosis`
#
# Show the summary output table for this model.

# %%
transformed_model_formula = smf.ols(formula="radius_mean ~ texture_mean + perimeter_mean + sqrt_area_mean + diagnosis", data=wdbc).fit()

transformed_model_formula.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            radius_mean   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.019e+05
# Date:                Tue, 03 Oct 2023   Prob (F-statistic):               0.00
# Time:                        23:53:47   Log-Likelihood:                 543.95
# No. Observations:                 569   AIC:                            -1078.
# Df Residuals:                     564   BIC:                            -1056.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 9.4. Linear Regression Equation
#
# Write out the linear regression equation for this model. Be sure to use appropriate notation.

# %% [markdown]
# The linear regression equation for the model can be written as:
#
# \begin{align*}
# \hat{y} = 0.2803 - 0.0016 \times \text{texture\_mean} + 0.0384 \times \text{perimeter\_mean} + 0.4180 \times \text{sqrt\_area\_mean} - 0.0750 \times \text{diagnosis}
# \end{align*}
#
# Where:
# - $ \hat{y} $ is the predicted `radius_mean`.
# - `diagnosis` is a dummy variable, where 1 indicates a malignant tumor and 0 indicates a benign tumor.

# %% [markdown]
# ### 9.5. Linearity Assumption
#
# 1. Is this transformed model *closer* to meeting the linearity assumption than the full model is?
# 2. Is a linear regression model a suitable type of model to reflect the relationship between the response variable `radius_mean` and the explanatory variables `texture_mean`, `perimeter_mean`, **`sqrt(area_mean)`**, `diagnosis` in this dataset? Explain.

# %%
wdbc['transformed_residuals'] = transformed_model_formula.resid
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

axes[0, 0].scatter(wdbc['texture_mean'], wdbc['transformed_residuals'], alpha=0.5)
axes[0, 0].set_title('Residuals vs. texture_mean')
axes[0, 0].set_xlabel('texture_mean')
axes[0, 0].set_ylabel('Residuals')
axes[0, 0].axhline(y=0, color='red', linestyle='--')

axes[0, 1].scatter(wdbc['perimeter_mean'], wdbc['transformed_residuals'], alpha=0.5)
axes[0, 1].set_title('Residuals vs. perimeter_mean')
axes[0, 1].set_xlabel('perimeter_mean')
axes[0, 1].set_ylabel('Residuals')
axes[0, 1].axhline(y=0, color='red', linestyle='--')

axes[1, 0].scatter(wdbc['sqrt_area_mean'], wdbc['transformed_residuals'], alpha=0.5)
axes[1, 0].set_title('Residuals vs. sqrt_area_mean')
axes[1, 0].set_xlabel('sqrt_area_mean')
axes[1, 0].set_ylabel('Residuals')
axes[1, 0].axhline(y=0, color='red', linestyle='--')

axes[1, 1].scatter(wdbc['diagnosis'], wdbc['transformed_residuals'], alpha=0.5)
axes[1, 1].set_title('Residuals vs. diagnosis')
axes[1, 1].set_xlabel('diagnosis')
axes[1, 1].set_ylabel('Residuals')
axes[1, 1].axhline(y=0, color='red', linestyle='--')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Yes, the transformed model, especially with the `sqrt_area_mean` predictor, appears to be closer to meeting the linearity assumption based on the scatterplots.
# 2. Yes, the scatterplots suggest that the relationships between the predictors and the response are linear, especially after transforming the `area_mean` variable. Thus, a linear regression model is suitable for this dataset.

# %% [markdown]
# ## 10. Model Evaluation
#
# ### 10.1. Model Suitability
#
# Is the full model or the transformed model a more suitable *type* of model to use reflect the nature of the relationship between the `radius_mean` response variable and the corresponding explanatory variables that were used in the models? Explain.

# %% [markdown]
# To determine which model is more suitable, we'll consider the following criteria:
#
# 1. **Residual plots**: The randomness and spread of residuals can indicate the suitability of the linear regression model.
# 2. **Adjusted R-squared**: This metric takes into account the number of predictors in the model. A higher adjusted R-squared indicates a better fit while penalizing excessive complexity.
# 3. **Complexity**: Simpler models (with fewer variables or transformations) are generally preferred, provided they have a similar explanatory power to more complex models.
#
# Given the models:
#
# - **Full Model**:
#   - Adjusted R-squared: 0.783
#   - Residuals showed patterns suggesting potential non-linearity, especially for `area_mean`.
#
# - **Transformed Model**:
#   - Adjusted R-squared: 0.785
#   - Residual plots appeared more random, especially for `sqrt_area_mean`, indicating better adherence to the linearity assumption.
#
# ### Answer:
#
# The **transformed model** seems to be a more suitable type of model to reflect the nature of the relationship between the `radius_mean` response variable and the corresponding explanatory variables. The transformation of `area_mean` improved the linearity of the model, and the adjusted R-squared is slightly higher than that of the full model. Even though the transformed model introduces an additional transformation step, this complexity is justified by the improved fit and adherence to the linearity assumption.

# %% [markdown]
# ### 10.2. Model Fit
#
# Which model provides a better *fit* of the dataset: the full model or the transformed model? Explain.

# %% [markdown]
# To determine which model provides a better fit, we should consider the following:
#
# 1. **Adjusted R-squared**: This metric provides an indication of the goodness of fit of the model. A higher value indicates that the model explains a larger proportion of the variance in the dependent variable, taking into account the number of predictors.
# 2. **Residual Plots**: A more random spread of residuals suggests a better fit to the linear regression assumptions.
# 3. **Statistical significance of predictors**: In a well-fitting model, more predictors are likely to be statistically significant.
#
# From the models we analyzed:
#
# - **Full Model**:
#   - Adjusted R-squared: 0.783
#   - Some residual plots suggested potential non-linearity.
#   - Some predictors were not statistically significant.
#
# - **Transformed Model**:
#   - Adjusted R-squared: 0.785
#   - Residual plots were closer to randomness, suggesting better adherence to the linearity assumption.
#   - All predictors were statistically significant.
#
# ### Answer:
#
# The **transformed model** provides a slightly better fit to the dataset compared to the full model. This is evident from the slightly higher adjusted R-squared value and the more random scatter in the residual plots, especially after transforming the `area_mean` variable. Furthermore, the predictors in the transformed model were statistically significant, further emphasizing its superior fit to the data.
